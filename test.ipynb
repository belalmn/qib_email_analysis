# %%
import torch
import transformers
from langchain import HuggingFacePipeline, LLMChain, PromptTemplate
from transformers import AutoModel, AutoTokenizer
import pandas as pd
from tqdm import tqdm
tqdm.pandas()

# THRESHOLD = 0.09

spam_classifier = transformers.pipeline(
    task="text-classification",
    model="mrm8488/bert-tiny-finetuned-sms-spam-detection",
    device="cuda" if torch.cuda.is_available() else "cpu",
)

# model_name = "mrm8488/bert-tiny-finetuned-sms-spam-detection" 

# model = AutoModel.from_pretrained(model_name)
# tokenizer = AutoTokenizer.from_pretrained(model_name)

def classify_spam(df: pd.DataFrame) -> pd.DataFrame:
    def _classify_spam(message: str) -> bool:
        # inputs = tokenizer("Hello world!", return_tensors="pt")
        # outputs = model(**inputs)
        # result = torch.nn.functional.softmax(outputs.logits, dim=-1)
        result = spam_classifier(message)
        

    
    return df
# Out:
# /home/belalm/miniconda3/envs/qib/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
df = pd.read_csv('./data/interim/sample_preprocessed_messages.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               50 non-null     int64
#  1   message_id               50 non-null     object
#  2   subject                  50 non-null     object
#  3   subject_prefix           2 non-null      object
#  4   submit_time              50 non-null     object
#  5   delivery_time            50 non-null     object
#  6   html_body                49 non-null     object
#  7   plain_text_body          49 non-null     object
#  8   from_name                50 non-null     object
#  9   from_address             50 non-null     object
#  10  to_address               50 non-null     object
#  11  cc_address               1 non-null      object
#  12  bcc_address              0 non-null      float64
#  13  previous_message_id      1 non-null      object
# ...

# %%
classified_messages = classify_spam(df)
# Out:
#   2%|▏         | 1/50 [00:00<00:00, 3830.41it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 classified_messages = classify_spam(df)
#
# Cell In[1], line 32, in classify_spam(df)
#      29     print(result)
#      30     return result[0]["score"]
# ---> 32 df["spam_score"] = df["clean_text"].progress_apply(lambda x: _classify_spam(str(x)))
#      33 return df
#
# File ~/miniconda3/envs/qib/lib/python3.11/site-packages/tqdm/std.py:917, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     914 # Apply the provided function (in **kwargs)
#     915 # on the df using our wrapper (which provides bar updating)
#     916 try:
# --> 917     return getattr(df, df_function)(wrapper, **kwargs)
#     918 finally:
#     919     t.close()
#
# ...

# %%
classified_messages.head()
