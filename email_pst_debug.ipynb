# %%
from src.utils.pypff_debug_utils import PST_DEBUG_TOOL
import pypff
from IPython.core.display import HTML

# %%
help(pypff.message)
# Out:
# Help on class message in module pypff:
#
# class message(item)
#  |  pypff message object (wraps message type libpff_item_t)
#  |
#  |  Method resolution order:
#  |      message
#  |      item
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  get_attachment(...)
#  |      get_attachment(attachment_index) -> Object or None
#  |
#  |      Retrieves a specific attachment.
#  |
#  |  get_client_submit_time(...)
#  |      get_client_submit_time() -> Datetime or None
#  |
#  |      Returns the client submit date and time.
#  |
#  |  get_client_submit_time_as_integer(...)
#  |      get_client_submit_time_as_integer() -> Integer or None
#  |
#  |      Returns the client submit date and time as a 64-bit integer containing a FILETIME value.
#  |
#  |  get_conversation_topic(...)
#  |      get_conversation_topic() -> Unicode string or None
#  |
#  |      Retrieves the conversation topic.
#  |
#  |  get_creation_time(...)
#  |      get_creation_time() -> Datetime or None
# ...

# %%
pst = PST_DEBUG_TOOL('./data/raw/emails.pst')

# %%
message = pst.message_from_id(2097188, 'Inbox')

# %%
print(message.get_transport_headers())
# Out:
# Delivered-To: belal.mnur@gmail.com
# Received: by 2002:a2e:9c45:0:b0:2ea:dea9:cec4 with SMTP id t5csp831199ljj;
#         Sat, 29 Jun 2024 22:06:26 -0700 (PDT)
# X-Forwarded-Encrypted: i=2; AJvYcCWxAZchi+WxkCPDOcguHaG5ft2IEZI7XpLff3CVRqHJe3uaIqe8EYVpLFFtTrQD1wpcb57JyMWAMHFqYx4RoDjLg9hCBg==
# X-Received: by 2002:a05:6512:1599:b0:52c:dc69:28f3 with SMTP id 2adb3069b0e04-52e8270fa7dmr1598603e87.52.1719723985943;
#         Sat, 29 Jun 2024 22:06:25 -0700 (PDT)
# ARC-Seal: i=1; a=rsa-sha256; t=1719723985; cv=none;
#         d=google.com; s=arc-20160816;
#         b=NCbYq+pk20xBJ8A0E+nkqsX14MfCnGZ2RUYSv0B+AmMTVQjLMTOW+HvatQ/MJMITiW
#          RGoMevNaakSxLiL6A9hOjFLBPy67THT8Md5V20enaeyCEzP12br9x+izZSXC33PHCk1K
#          81q3z1rG2wWR3SO8PNgoYBFiP5gOuwZq1DtnGsyM3buog0oGyRQiS/ls2Y28vubcgc4y
#          Uy38CWblcOIYgIE2NWXid9RukTDzNWLuLMVYlhPQHMgnADxN1xVSq+35/BJIX957vU1n
#          YaeVl8XK/AOjn3h4x3yflJStLXWwGdJ/QFJ8FpjhyeBQIIRLKIEJhD++PREQISJLxThR
#          z2ZQ==
# ...
